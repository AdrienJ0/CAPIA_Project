# %% [markdown]
# This notebook reports the performance of the different models trained

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
tensorboard --log_dir Models/model_with_mask_plein_clahe20241024/logs/fit --port 6020
# Out:
# Launching TensorBoard...

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir Models/model_with_sclero_&_clahe_20240406/logs/fit --port 6018
# Out:
# Reusing TensorBoard on port 6018 (pid 18364), started 0:03:03 ago. (Use '!kill 18364' to kill it.)
#       <iframe id="tensorboard-frame-6605409c606ba267" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6605409c606ba267");
#           const url = new URL("http://localhost");
#           const port = 6018;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Metrics on the validation set:
#
#     Batchsize: 4
#     Initial learning rate: 0.01
#     Accuracy: 0.98231
#     F1: 0.30667
#     Jaccard: 0.18384
#     Recall: 0.41738
#     Precision: 0.26049
#
#
# Metrics on the training set:
#
#     Accuracy: 0.97442
#     F1: 0.43126
#     Jaccard: 0.29081
#     Recall: 0.36319
#     Precision: 0.62179

# %% [markdown]
# Analyse:
#
# - Bonnes courbes de loss -> pas vraiment d'overfitting
# - Meilleur courbe pour l'instant ?

# %%
# %tensorboard --logdir Models/model_with_clahe_20240406/logs/fit --port 6011

# %%
# %tensorboard --logdir Models/model_with_mask_plein_clahe20240411/logs/fit --port 6017
# Out:
# Reusing TensorBoard on port 6017 (pid 22776), started 0:00:11 ago. (Use '!kill 22776' to kill it.)
#       <iframe id="tensorboard-frame-36e468fe2127dc35" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-36e468fe2127dc35");
#           const url = new URL("http://localhost");
#           const port = 6017;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Metrics on the validation set:
#
#     #On mask non pleins
#     - Accuracy: 0.98591
#     - F1: 0.16085
#     - Jaccard: 0.09328
#     - Recall: 0.20131
#     - Precision: 0.26152
#
#     #On masks pleins
#     - Accuracy: 0.97346
#     - F1: 0.49417
#     - Jaccard: 0.33606
#     - Recall: 0.57244
#     - Precision: 0.45267
#
#
# Metrics on the training set:
#
#     - Accuracy: 0.98227
#     - F1: 0.69204
#     - Jaccard: 0.54569
#     - Recall: 0.78757
#     - Precision: 0.64565

# %%
# !kill 39648

# %% [markdown]
# - Courbes de loss pas très bonnes

# %%
# %tensorboard --logdir Models/model_with_mask_plein_clahe20240508/logs/fit --port 6016
# Out:
# Reusing TensorBoard on port 6016 (pid 23152), started 0:00:03 ago. (Use '!kill 23152' to kill it.)
#       <iframe id="tensorboard-frame-81f990d27e7a3ab4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-81f990d27e7a3ab4");
#           const url = new URL("http://localhost");
#           const port = 6016;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Il semble y avoir un overfitting
#
# Pistes d'optimisation:
# - Essayer une L1 et L2 REGULARIZATION

# %% [markdown]
# Metrics on the validation set:
#
#     Accuracy: 0.97853
#     F1: 0.49395
#     Jaccard: 0.34210
#     Recall: 0.50329
#     Precision: 0.56926
#
# Metrics on the training set:
#
#     Accuracy: 0.97813
#     F1: 0.55719
#     Jaccard: 0.40605
#     Recall: 0.55987
#     Precision: 0.62025
